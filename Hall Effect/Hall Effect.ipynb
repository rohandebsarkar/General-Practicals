# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import scienceplots
plt.style.use(['science','ieee', 'grid'])
plt.rcParams["figure.figsize"] = (10, 6)

Z = 5e-4

# %% [markdown]
# ## Constant B

# %%
data1 = pd.read_csv("data1.csv")

data1
# Out:
#     I_B (A)  B (KG)  I (mA)  Hall Voltage [FB FI] (mV)  \
# 0       0.5  1.0335     1.0                        3.2
# 1       0.5  1.0335     1.5                        4.7
# 2       0.5  1.0335     2.0                        6.0
# 3       0.5  1.0335     2.5                        7.9
# 4       0.5  1.0335     3.0                        9.2
# 5       1.0  1.8400     1.0                        7.1
# 6       1.0  1.8400     1.5                       11.2
# 7       1.0  1.8400     2.0                       14.9
# 8       1.0  1.8400     2.5                       18.5
# 9       1.0  1.8400     3.0                       22.6
# 10      1.5  2.6465     1.0                       11.2
# 11      1.5  2.6465     1.5                       16.4
# 12      1.5  2.6465     2.0                       22.1
# 13      1.5  2.6465     2.5                       27.2
# 14      1.5  2.6465     3.0                       32.8
# 15      2.0  3.4530     1.0                       14.9
# 16      2.0  3.4530     1.5                       22.3
# 17      2.0  3.4530     2.0                       29.7
# 18      2.0  3.4530     2.5                       36.7
# 19      2.0  3.4530     3.0                       43.5
#
#     Hall Voltage [FB RI] (mV)  Hall Voltage [RB FI] (mV)  \
# 0                         3.2                        3.8
# 1                         4.8                        5.8
# 2                         6.2                        7.4
# 3                         8.3                        9.6
# 4                         9.8                       11.0
# 5                         7.4                        8.4
# 6                        11.2                       12.0
# 7                        14.9                       16.8
# 8                        18.4                       20.5
# 9                        21.6                       24.5
# 10                       11.2                       12.0
# 11                       16.3                       18.2
# 12                       22.1                       24.4
# 13                       27.2                       30.2
# 14                       32.6                       36.5
# 15                       14.8                       15.8
# 16                       22.0                       24.4
# 17                       29.3                       32.2
# 18                       36.5                       40.4
# 19                       43.2                       47.5
#
#     Hall Voltage [RB RI] (mV)  Mean Hall Voltage (mV)
# 0                         3.6                     3.5
# 1                         5.5                     5.2
# 2                         7.2                     6.7
# 3                         9.0                     8.7
# 4                         9.6                     9.9
# 5                         8.7                     7.9
# 6                        12.6                    11.8
# 7                        17.0                    15.9
# 8                        20.8                    19.6
# 9                        24.9                    23.4
# 10                       12.4                    11.7
# 11                       18.5                    17.4
# 12                       24.4                    23.3
# 13                       29.8                    28.6
# 14                       36.3                    34.6
# 15                       16.1                    15.4
# 16                       24.3                    23.3
# 17                       32.0                    30.8
# 18                       40.2                    38.5
# 19                       47.4                    45.4

# %%
B = np.unique(data1["B (KG)"])
x=np.zeros((4, 5))
y=np.zeros((4, 5))
m=np.zeros(4)
for i in range(len(B)):
    x[i] = data1[data1["B (KG)"] == B[i]]["I (mA)"]
    y[i] = data1[data1["B (KG)"] == B[i]]["Mean Hall Voltage (mV)"]
    plt.plot(x[i], y[i], ".")

for i in range(len(x)):
    m[i] = np.sum(x[i] * y[i]) / np.sum(x[i]**2)
    plt.plot(np.append(0, x[i]), m[i]*np.append(0, x[i]), label=f"B = {B[i]}")

plt.show()

# %%
R=np.zeros(4)
for i in range(len(m)):
    R[i]=m[i]*Z/B[i]

np.mean(R)
# Out:
# np.float64(0.0020418271518718284)

# %% [markdown]
# ## Constant I

# %%
data2 = pd.read_csv("data2.csv")

data2
# Out:
#     I (mA)  I_B (A)  B (KG)  Hall Voltage [FB FI] (mV)  \
# 0      1.0      0.5    1.03                        2.7
# 1      1.0      1.0    1.84                        7.2
# 2      1.0      1.5    2.65                       11.0
# 3      1.0      2.0    3.45                       14.8
# 4      1.0      2.5    4.26                       17.9
# 5      1.5      0.5    1.03                        4.1
# 6      1.5      1.0    1.84                       10.5
# 7      1.5      1.5    2.65                       16.4
# 8      1.5      2.0    3.45                       21.5
# 9      1.5      2.5    4.26                       26.4
# 10     2.0      0.5    1.03                        6.7
# 11     2.0      1.0    1.84                       15.5
# 12     2.0      1.5    2.65                       23.4
# 13     2.0      2.0    3.45                       29.8
# 14     2.0      2.5    4.26                       35.9
# 15     2.5      0.5    1.03                        6.4
# 16     2.5      1.0    1.84                       17.4
# 17     2.5      1.5    2.65                       26.8
# 18     2.5      2.0    3.45                       35.8
# 19     2.5      2.5    4.26                       43.4
#
#     Hall Voltage [FB RI] (mV)  Hall Voltage [RB FI] (mV)  \
# 0                         2.9                        4.9
# 1                         6.9                        9.2
# 2                        10.7                       13.1
# 3                        14.4                       16.5
# 4                        17.7                       19.3
# 5                         4.1                        7.2
# 6                        10.4                       13.5
# 7                        16.1                       19.2
# 8                        21.6                       24.7
# 9                        26.0                       29.3
# 10                        6.6                        8.2
# 11                       15.5                       17.2
# 12                       23.0                       24.6
# 13                       29.7                       32.5
# 14                       34.8                       38.3
# 15                        5.8                       12.2
# 16                       17.2                       23.4
# 17                       26.8                       32.6
# 18                       35.9                       41.0
# 19                       43.2                       47.5
#
#     Hall Voltage [RB RI] (mV)  Mean Hall Voltage (mV)
# 0                         5.1                     3.9
# 1                         9.5                     8.2
# 2                        13.2                    12.0
# 3                        16.7                    15.6
# 4                        19.5                    18.6
# 5                         7.6                     5.8
# 6                        13.6                    12.0
# 7                        19.3                    17.8
# 8                        24.6                    23.1
# 9                        29.1                    27.7
# 10                        8.1                     7.4
# 11                       17.0                    16.3
# 12                       24.6                    23.9
# 13                       32.4                    31.1
# 14                       38.3                    36.8
# 15                       12.0                     9.1
# 16                       23.2                    20.3
# 17                       32.6                    29.7
# 18                       40.9                    38.4
# 19                       47.7                    45.5

# %%
I = np.unique(data2["I (mA)"])
x=np.zeros((4, 5))
y=np.zeros((4, 5))
m=np.zeros(4)
for i in range(len(I)):
    x[i] = data2[data2["I (mA)"] == I[i]]["B (KG)"]
    y[i] = data2[data2["I (mA)"] == I[i]]["Mean Hall Voltage (mV)"]
    plt.plot(x[i], y[i], ".")

for i in range(len(x)):
    m[i] = np.sum(x[i] * y[i]) / np.sum(x[i]**2)
    plt.plot(np.append(0, x[i]), m[i]*np.append(0, x[i]), label=f"I = {I[i]}")

plt.legend()
plt.show()

# %%
R=np.zeros(4)
for i in range(len(m)):
    R[i]=m[i]*Z/I[i]

np.mean(R)
# Out:
# np.float64(0.0021951051845215015)
